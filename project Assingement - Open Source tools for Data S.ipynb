# %% [markdown]
# # My Jupyter Notebook on IBM Data Science Experience

# %% [markdown]
# **Martin Werz**
# current job Trainee
# desired job Data Scientist

# %% [markdown]
# *I am interested in Data Science because I realised that this came extremly close to my natural personalitiy because I like to learn every day new things and also I
#  extremly curios person. Additionaly I always seaching for oppurtinieties to improve my working results.*

# %% [markdown]
# ### The result of 7^3

# %%
7*7*7
# Out:
# 343

# %% [markdown]
# #### Neighbour Countrys of Switzerland
# - Germany
# - Liechtenstein
# - Austria
# - Italy
# - France
#
# #### Link to Switzerlands Conistitution
# [I'm an inline-style link](https://www.admin.ch/opc/en/classified-compilation/19995395/index.html)
#
# ### Image of Switzerland
# ![Switzerland](data:image/png;base64,...)
